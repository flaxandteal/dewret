# %% [markdown]
# # Fixed

# %% [markdown]
# ## Working examples

# %% [markdown]
# ### global annotation (example from tests)

# %%
from dewret.renderers.cwl import render
from dewret.tasks import task, construct, workflow
from dewret.annotations import Fixed

list_2: Fixed[list[int]] = [0, 1, 2, 3]

@workflow()
def loop_over_lists(list_1: list[int]) -> list[int]:
    result = []
    for a, b in zip(list_1, list_2, strict=False):
        result.append(a + b + len(list_2))
    return result


result = loop_over_lists(list_1=[10, 20, 30, 40])
workflow = construct(result, simplify_ids=True)
cwl = render(workflow)
cwl
# Out:
# {'__root__': {'cwlVersion': 1.2,
#   'class': 'Workflow',
#   'inputs': {'loop_over_lists-1-list_1': {'label': 'list_1',
#     'type': 'array',
#     'items': 'int',
#     'default': [10, 20, 30, 40]}},
#   'outputs': {'out': {'label': 'out',
#     'type': 'array',
#     'items': 'int',
#     'outputSource': 'loop_over_lists-1/out'}},
#   'steps': {'loop_over_lists-1': {'run': 'loop_over_lists',
#     'in': {'list_1': {'source': 'loop_over_lists-1-list_1'}},
#     'out': ['out']}}},
#  'loop_over_lists-1': {'cwlVersion': 1.2,
#   'class': 'Workflow',
#   'inputs': {},
#   'outputs': {'out': {'type': 'float',
#     'label': 'out',
#     'expression': '[list_1[0] + list_2[0] + 4, list_1[1] + list_2[1] + 4, list_1[2] + list_2[2] + 4, list_1[3] + list_2[3] + 4]',
#     'source': ['list_1', 'list_2']}},
#   'steps': {}}}

# %% [markdown]
# ### parameter annotation

# %%
from dewret.renderers.cwl import render
from dewret.tasks import construct, workflow
from dewret.annotations import Fixed

@workflow()
def loop_over_lists(list_1: Fixed[list[int]]) -> list[int]:
    result = []
    for a, b in zip(list_1, list_1, strict=False):
        result.append(a + b + len(list_1))
    return result


result = loop_over_lists(list_1=[10, 20, 30, 40])
workflow = construct(result, simplify_ids=True)
cwl = render(workflow)
cwl
# Out:
# {'__root__': {'cwlVersion': 1.2,
#   'class': 'Workflow',
#   'inputs': {'loop_over_lists-1-list_1': {'label': 'list_1',
#     'type': 'array',
#     'items': 'int',
#     'default': [10, 20, 30, 40]}},
#   'outputs': {'out': {'label': 'out',
#     'type': 'array',
#     'items': 'int',
#     'outputSource': 'loop_over_lists-1/out'}},
#   'steps': {'loop_over_lists-1': {'run': 'loop_over_lists',
#     'in': {'list_1': {'source': 'loop_over_lists-1-list_1'}},
#     'out': ['out']}}},
#  'loop_over_lists-1': {'cwlVersion': 1.2,
#   'class': 'Workflow',
#   'inputs': {},
#   'outputs': {'out': {'type': 'float',
#     'label': 'out',
#     'expression': '[2*list_1[0] + 4, 2*list_1[1] + 4, 2*list_1[2] + 4, 2*list_1[3] + 4]',
#     'source': ['list_1']}},
#   'steps': {}}}

# %% [markdown]
# ### simple iteration of a task over a list

# %% [markdown]
# This example shows the main use of the Fixed annotation

# %%
""" from dewret.renderers.cwl import render
from dewret.tasks import construct, workflow, task
from dewret.annotations import Fixed

@task()
def work(arg: int) -> int:
    # do work
    return arg # need to return something or the loop is optimized away

@workflow()
def loop_work(list: Fixed[list[int]]) -> list[int]:
    # result = []
    # for i in list:
    #     work(arg = i)
    #     result.append(i) 
    result = [work(arg = i) for i in list]

    return result

result = loop_work(list=[1,2])
workflow = construct(result, simplify_ids=True)
cwl = render(workflow)
cwl """
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File c:\Users\esc\miniconda3\envs\0.12-env\Lib\site-packages\dewret\tasks.py:641, in task.<locals>._task.<locals>._fn(__workflow__, __traceback__, *args, **kwargs)
#     640 with in_nested_task():
# --> 641     output = analyser.with_new_globals(nested_globals)(
#     642         **nested_kwargs
#     643     )
#     644     nested_workflow = _manager(
#     645         output, __workflow__=nested_workflow
#     646     )
#
# Cell In[4], line 16, in loop_work(list)
#      10 @workflow()
#      11 def loop_work(list: Fixed[list[int]]) -> list[int]:
#      12     # result = []
#      13     # for i in list:
#      14     #     work(arg = i)
#      15     #     result.append(i)
# ---> 16     result = [work(arg = i) for i in list]
#      18     return result
#
# Cell In[4], line 16, in <listcomp>(.0)
#      10 @workflow()
#      11 def loop_work(list: Fixed[list[int]]) -> list[int]:
#      12     # result = []
#      13     # for i in list:
#      14     #     work(arg = i)
#      15     #     result.append(i)
# ---> 16     result = [work(arg = i) for i in list]
#      18     return result
#
# NameError: name 'work' is not defined
#
# The above exception was the direct cause of the following exception:
#
# TaskException                             Traceback (most recent call last)
# Cell In[4], line 20
#      16     result = [work(arg = i) for i in list]
#      18     return result
# ---> 20 result = loop_work(list=[1,2])
#      21 workflow = construct(result, simplify_ids=True)
#      22 cwl = render(workflow)
#
# File c:\Users\esc\miniconda3\envs\0.12-env\Lib\site-packages\dewret\workflow.py:106, in LazyEvaluation.__call__(self, *args, **kwargs)
#      97 """Wrapper around a lazy execution.
#      98
#      99 Captures a traceback, for debugging if this does not work.
#    (...)    103 is attempted.
#     104 """
#     105 tb = make_traceback()
# --> 106 result = self._fn(*args, **kwargs, __traceback__=tb)  # type: ignore[arg-type]
#     107 return result
#
# File c:\Users\esc\miniconda3\envs\0.12-env\Lib\site-packages\dewret\tasks.py:673, in task.<locals>._task.<locals>._fn(__workflow__, __traceback__, *args, **kwargs)
#     671     raise exc
#     672 except Exception as exc:
# --> 673     raise TaskException(
#     674         fn,
#     675         declaration_tb,
#     676         __traceback__,
#     677         exc.args[0] if exc.args else f"Could not call task {fn.__name__}",
#     678     ) from exc
#     679 finally:
#     680     if configuration:
#
# File <frozen runpy>:198, in _run_module_as_main(mod_name, alter_argv)
#
# File <frozen runpy>:88, in _run_code(code, run_globals, init_globals, mod_name, mod_spec, pkg_name, script_name)
#
# File c:\Users\esc\miniconda3\envs\0.12-env\Lib\site-packages\ipykernel_launcher.py:18
#      14     del sys.path[0]
#      16 from ipykernel import kernelapp as app
# ---> 18 app.launch_new_instance()
#
# File c:\Users\esc\miniconda3\envs\0.12-env\Lib\site-packages\traitlets\config\application.py:1075, in Application.launch_instance(cls, argv, **kwargs)
#    1073 app = cls.instance(**kwargs)
#    1074 app.initialize(argv)
# -> 1075 app.start()
#
# File c:\Users\esc\miniconda3\envs\0.12-env\Lib\site-packages\ipykernel\kernelapp.py:739, in IPKernelApp.start(self)
#     737 else:
#     738     try:
# --> 739         self.io_loop.start()
#     740     except KeyboardInterrupt:
#     741         pass
#
# File c:\Users\esc\miniconda3\envs\0.12-env\Lib\site-packages\tornado\platform\asyncio.py:211, in BaseAsyncIOLoop.start(self)
#     210 def start(self) -> None:
# --> 211     self.asyncio_loop.run_forever()
#
# File c:\Users\esc\miniconda3\envs\0.12-env\Lib\asyncio\base_events.py:608, in BaseEventLoop.run_forever(self)
#     606 events._set_running_loop(self)
#     607 while True:
# --> 608     self._run_once()
#     609     if self._stopping:
#     610         break
#
# File c:\Users\esc\miniconda3\envs\0.12-env\Lib\asyncio\base_events.py:1936, in BaseEventLoop._run_once(self)
#    1934             self._current_handle = None
#    1935     else:
# -> 1936         handle._run()
#    1937 handle = None
#
# File c:\Users\esc\miniconda3\envs\0.12-env\Lib\asyncio\events.py:84, in Handle._run(self)
#      82 def _run(self):
#      83     try:
# ---> 84         self._context.run(self._callback, *self._args)
#      85     except (SystemExit, KeyboardInterrupt):
#      86         raise
#
# File c:\Users\esc\miniconda3\envs\0.12-env\Lib\site-packages\ipykernel\kernelbase.py:516, in Kernel.dispatch_queue(self)
#     514 while True:
#     515     try:
# --> 516         await self.process_one()
#     517     except Exception:
#     518         self.log.exception("Error in message handler")
#
# File c:\Users\esc\miniconda3\envs\0.12-env\Lib\site-packages\ipykernel\kernelbase.py:505, in Kernel.process_one(self, wait)
#     502         await asyncio.sleep(0)
#     503         self.control_stream.flush()
# --> 505 await dispatch(*args)
#
# File c:\Users\esc\miniconda3\envs\0.12-env\Lib\site-packages\ipykernel\kernelbase.py:397, in Kernel.dispatch_shell(self, msg)
#     395     result = handler(self.shell_stream, idents, msg)
#     396     if inspect.isawaitable(result):
# --> 397         await result
#     398 except Exception:
#     399     self.log.error("Exception in message handler:", exc_info=True)  # noqa: G201
#
# File c:\Users\esc\miniconda3\envs\0.12-env\Lib\site-packages\ipykernel\ipkernel.py:368, in IPythonKernel.execute_request(self, stream, ident, parent)
#     366 parent_header = extract_header(parent)
#     367 self._associate_new_top_level_threads_with(parent_header)
# --> 368 await super().execute_request(stream, ident, parent)
#
# File c:\Users\esc\miniconda3\envs\0.12-env\Lib\site-packages\ipykernel\kernelbase.py:752, in Kernel.execute_request(self, stream, ident, parent)
#     749 reply_content = self.do_execute(**do_execute_args)
#     751 if inspect.isawaitable(reply_content):
# --> 752     reply_content = await reply_content
#     754 # Flush output before sending the reply.
#     755 if sys.stdout is not None:
#
# File c:\Users\esc\miniconda3\envs\0.12-env\Lib\site-packages\ipykernel\ipkernel.py:455, in IPythonKernel.do_execute(self, code, silent, store_history, user_expressions, allow_stdin, cell_meta, cell_id)
#     450 else:
#     451     # runner isn't already running,
#     452     # make synchronous call,
#     453     # letting shell dispatch to loop runners
#     454     if accepts_params["cell_id"]:
# --> 455         res = shell.run_cell(
#     456             code,
#     457             store_history=store_history,
#     458             silent=silent,
#     459             cell_id=cell_id,
#     460         )
#     461     else:
#     462         res = shell.run_cell(code, store_history=store_history, silent=silent)
#
# File c:\Users\esc\miniconda3\envs\0.12-env\Lib\site-packages\ipykernel\zmqshell.py:577, in ZMQInteractiveShell.run_cell(self, *args, **kwargs)
#     575 """Run a cell."""
#     576 self._last_traceback = None
# --> 577 return super().run_cell(*args, **kwargs)
#
# File c:\Users\esc\miniconda3\envs\0.12-env\Lib\site-packages\IPython\core\interactiveshell.py:3116, in InteractiveShell.run_cell(self, raw_cell, store_history, silent, shell_futures, cell_id)
#    3114 with self._tee(channel="stdout"), self._tee(channel="stderr"):
#    3115     try:
# -> 3116         result = self._run_cell(
#    3117             raw_cell, store_history, silent, shell_futures, cell_id
#    3118         )
#    3119     finally:
#    3120         self.events.trigger("post_execute")
#
# File c:\Users\esc\miniconda3\envs\0.12-env\Lib\site-packages\IPython\core\interactiveshell.py:3171, in InteractiveShell._run_cell(self, raw_cell, store_history, silent, shell_futures, cell_id)
#    3168     runner = _pseudo_sync_runner
#    3170 try:
# -> 3171     result = runner(coro)
#    3172 except BaseException as e:
#    3173     try:
#
# File c:\Users\esc\miniconda3\envs\0.12-env\Lib\site-packages\IPython\core\async_helpers.py:128, in _pseudo_sync_runner(coro)
#     120 """
#     121 A runner that does not really allow async execution, and just advance the coroutine.
#     122
#    (...)    125 Credit to Nathaniel Smith
#     126 """
#     127 try:
# --> 128     coro.send(None)
#     129 except StopIteration as exc:
#     130     return exc.value
#
# File c:\Users\esc\miniconda3\envs\0.12-env\Lib\site-packages\IPython\core\interactiveshell.py:3394, in InteractiveShell.run_cell_async(self, raw_cell, store_history, silent, shell_futures, transformed_cell, preprocessing_exc_tuple, cell_id)
#    3390 # Execute the user code
#    3391 interactivity = "none" if silent else self.ast_node_interactivity
# -> 3394 has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    3395        interactivity=interactivity, compiler=compiler, result=result)
#    3397 self.last_execution_succeeded = not has_raised
#    3398 self.last_execution_result = result
#
# File c:\Users\esc\miniconda3\envs\0.12-env\Lib\site-packages\IPython\core\interactiveshell.py:3639, in InteractiveShell.run_ast_nodes(self, nodelist, cell_name, interactivity, compiler, result)
#    3637         code = compiler(mod, cell_name, mode)
#    3638         asy = compare(code)
# -> 3639     if await self.run_code(code, result, async_=asy):
#    3640         return True
#    3642 # Flush softspace
#
#     [... skipping hidden 1 frame]
#
# Cell In[4], line 20
#      16     result = [work(arg = i) for i in list]
#      18     return result
# ---> 20 result = loop_work(list=[1,2])
#      21 workflow = construct(result, simplify_ids=True)
#      22 cwl = render(workflow)
#
# TaskException: name 'work' is not defined
# Task loop_work declared in <module> at C:\Users\esc\AppData\Local\Temp\ipykernel_355556\4210941050.py:10
# @workflow()

# %%
cwl.keys()
# Out:
# dict_keys(['__root__', 'loop_work-1'])

# %%
cwl['loop_work-1']['steps']
# Out:
# {'work-1-1': {'run': 'work',
#   'in': {'arg': {'source': 'list[1]'}},
#   'out': ['out']},
#  'work-1-2': {'run': 'work',
#   'in': {'arg': {'source': 'list[0]'}},
#   'out': ['out']}}

# %% [markdown]
# ### Render time loops don't have to be annotated as `Fixed`

# %%
from dewret.renderers.cwl import render
from dewret.tasks import construct, workflow, task
from dewret.annotations import AtRender

list_2: AtRender[list[int]] = [0, 1, 2, 3]

# This task is needed to ensure something gets rendered, note the type isn't enforced
@task()
def iden(arg: str) -> str:
    return arg

@workflow()
def loop_over_lists() -> list[int]:
    result = []
    for a, b in zip(list_2, list_2, strict=False):
        result.append(a + b + len(list_2))
    return iden(arg = result)

result = loop_over_lists()
workflow = construct(result, simplify_ids=True)
cwl = render(workflow)
cwl
# Out:
# {'__root__': {'cwlVersion': 1.2,
#   'class': 'Workflow',
#   'inputs': {},
#   'outputs': {'out': {'label': 'out',
#     'type': 'array',
#     'items': 'int',
#     'outputSource': 'loop_over_lists-1/out'}},
#   'steps': {'loop_over_lists-1': {'run': 'loop_over_lists',
#     'in': {},
#     'out': ['out']}}},
#  'loop_over_lists-1': {'cwlVersion': 1.2,
#   'class': 'Workflow',
#   'inputs': {},
#   'outputs': {'out': {'label': 'out',
#     'type': 'string',
#     'outputSource': 'iden-1-1/out'}},
#   'steps': {'iden-1-1': {'run': 'iden',
#     'in': {'arg': {'default': [4, 6, 8, 10]}},
#     'out': ['out']}}}}

# %%
from dewret.renderers.cwl import render
from dewret.tasks import construct, workflow, task
from dewret.annotations import AtRender

@task()
def work(arg: int) -> int:
    # do work
    return arg # need to return something or the loop is optimized away

@workflow()
def loop_work(list: AtRender[list[int]]) -> list[int]:
    result = []
    for i in list:
        res = work(arg = i)
        result.append(res) 

    return result

result = loop_work(list=[1,2])
workflow = construct(result, simplify_ids=True)
cwl = render(workflow)
cwl
# Out:
# {'__root__': {'cwlVersion': 1.2,
#   'class': 'Workflow',
#   'inputs': {},
#   'outputs': {'out': {'label': 'out',
#     'type': 'array',
#     'items': 'int',
#     'outputSource': 'loop_work-1/out'}},
#   'steps': {'loop_work-1': {'run': 'loop_work',
#     'in': {'list': {'default': [1, 2]}},
#     'out': ['out']}}},
#  'loop_work-1': {'cwlVersion': 1.2,
#   'class': 'Workflow',
#   'inputs': {},
#   'outputs': [{'label': 'out', 'type': 'int', 'outputSource': 'work-1-1/out'},
#    {'label': 'out', 'type': 'int', 'outputSource': 'work-1-2/out'}],
#   'steps': {'work-1-1': {'run': 'work',
#     'in': {'arg': {'default': 1}},
#     'out': ['out']},
#    'work-1-2': {'run': 'work',
#     'in': {'arg': {'default': 2}},
#     'out': ['out']}}}}

# %%
cwl['loop_work-1']['steps']
# Out:
# {'work-1-1': {'run': 'work', 'in': {'arg': {'default': 1}}, 'out': ['out']},
#  'work-1-2': {'run': 'work', 'in': {'arg': {'default': 2}}, 'out': ['out']}}

# %% [markdown]
# ## Not working, as designed

# %% [markdown]
# Error message is helpful

# %%
from dewret.renderers.cwl import render
from dewret.tasks import construct, workflow, task

list_2: list[int] = [0, 1, 2, 3]

@task()
def iden(arg: str) -> str:
    return arg

@workflow()
def loop_over_lists() -> list[int]:
    result = []
    for a, b in zip(list_2, list_2, strict=False):
        result.append(a + b + len(list_2))
    return iden(arg = result)

result = loop_over_lists()
workflow = construct(result, simplify_ids=True)
cwl = render(workflow)
cwl
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\esc\miniconda3\envs\0.12-env\Lib\site-packages\dewret\tasks.py:641, in task.<locals>._task.<locals>._fn(__workflow__, __traceback__, *args, **kwargs)
#     640 with in_nested_task():
# --> 641     output = analyser.with_new_globals(nested_globals)(
#     642         **nested_kwargs
#     643     )
#     644     nested_workflow = _manager(
#     645         output, __workflow__=nested_workflow
#     646     )
#
# Cell In[11], line 14, in loop_over_lists()
#      13 for a, b in zip(list_2, list_2, strict=False):
# ---> 14     result.append(a + b + len(list_2))
#      15 return iden(arg = result)
#
# File c:\Users\esc\miniconda3\envs\0.12-env\Lib\site-packages\dewret\workflow.py:1659, in IterableParameterReference.__len__(self)
#    1658     return len(self.__default__)
# -> 1659 return super().__len__()
#
# File c:\Users\esc\miniconda3\envs\0.12-env\Lib\site-packages\dewret\core.py:534, in IterableMixin.__len__(self)
#     533 if self.__fixed_len__ is None:
# --> 534     raise TypeError(
#     535         "This iterable reference does not have a known fixed length, "
#     536         "consider using `Fixed[...]` with a default, or typehint using `tuple[int, float]` (or similar) "
#     537         "to tell dewret how long it should be."
#     538     )
#     539 return self.__fixed_len__
#
# TypeError: This iterable reference does not have a known fixed length, consider using `Fixed[...]` with a default, or typehint using `tuple[int, float]` (or similar) to tell dewret how long it should be.
#
# The above exception was the direct cause of the following exception:
#
# TaskException                             Traceback (most recent call last)
# Cell In[11], line 17
#      14         result.append(a + b + len(list_2))
#      15     return iden(arg = result)
# ---> 17 result = loop_over_lists()
#      18 workflow = construct(result, simplify_ids=True)
#      19 cwl = render(workflow)
#
# File c:\Users\esc\miniconda3\envs\0.12-env\Lib\site-packages\dewret\workflow.py:106, in LazyEvaluation.__call__(self, *args, **kwargs)
#      97 """Wrapper around a lazy execution.
#      98
#      99 Captures a traceback, for debugging if this does not work.
#    (...)    103 is attempted.
#     104 """
#     105 tb = make_traceback()
# --> 106 result = self._fn(*args, **kwargs, __traceback__=tb)  # type: ignore[arg-type]
#     107 return result
#
# File c:\Users\esc\miniconda3\envs\0.12-env\Lib\site-packages\dewret\tasks.py:673, in task.<locals>._task.<locals>._fn(__workflow__, __traceback__, *args, **kwargs)
#     671     raise exc
#     672 except Exception as exc:
# --> 673     raise TaskException(
#     674         fn,
#     675         declaration_tb,
#     676         __traceback__,
#     677         exc.args[0] if exc.args else f"Could not call task {fn.__name__}",
#     678     ) from exc
#     679 finally:
#     680     if configuration:
#
# File <frozen runpy>:198, in _run_module_as_main(mod_name, alter_argv)
#
# File <frozen runpy>:88, in _run_code(code, run_globals, init_globals, mod_name, mod_spec, pkg_name, script_name)
#
# File c:\Users\esc\miniconda3\envs\0.12-env\Lib\site-packages\ipykernel_launcher.py:18
#      14     del sys.path[0]
#      16 from ipykernel import kernelapp as app
# ---> 18 app.launch_new_instance()
#
# File c:\Users\esc\miniconda3\envs\0.12-env\Lib\site-packages\traitlets\config\application.py:1075, in Application.launch_instance(cls, argv, **kwargs)
#    1073 app = cls.instance(**kwargs)
#    1074 app.initialize(argv)
# -> 1075 app.start()
#
# File c:\Users\esc\miniconda3\envs\0.12-env\Lib\site-packages\ipykernel\kernelapp.py:739, in IPKernelApp.start(self)
#     737 else:
#     738     try:
# --> 739         self.io_loop.start()
#     740     except KeyboardInterrupt:
#     741         pass
#
# File c:\Users\esc\miniconda3\envs\0.12-env\Lib\site-packages\tornado\platform\asyncio.py:211, in BaseAsyncIOLoop.start(self)
#     210 def start(self) -> None:
# --> 211     self.asyncio_loop.run_forever()
#
# File c:\Users\esc\miniconda3\envs\0.12-env\Lib\asyncio\base_events.py:608, in BaseEventLoop.run_forever(self)
#     606 events._set_running_loop(self)
#     607 while True:
# --> 608     self._run_once()
#     609     if self._stopping:
#     610         break
#
# File c:\Users\esc\miniconda3\envs\0.12-env\Lib\asyncio\base_events.py:1936, in BaseEventLoop._run_once(self)
#    1934             self._current_handle = None
#    1935     else:
# -> 1936         handle._run()
#    1937 handle = None
#
# File c:\Users\esc\miniconda3\envs\0.12-env\Lib\asyncio\events.py:84, in Handle._run(self)
#      82 def _run(self):
#      83     try:
# ---> 84         self._context.run(self._callback, *self._args)
#      85     except (SystemExit, KeyboardInterrupt):
#      86         raise
#
# File c:\Users\esc\miniconda3\envs\0.12-env\Lib\site-packages\ipykernel\kernelbase.py:516, in Kernel.dispatch_queue(self)
#     514 while True:
#     515     try:
# --> 516         await self.process_one()
#     517     except Exception:
#     518         self.log.exception("Error in message handler")
#
# File c:\Users\esc\miniconda3\envs\0.12-env\Lib\site-packages\ipykernel\kernelbase.py:505, in Kernel.process_one(self, wait)
#     502         await asyncio.sleep(0)
#     503         self.control_stream.flush()
# --> 505 await dispatch(*args)
#
# File c:\Users\esc\miniconda3\envs\0.12-env\Lib\site-packages\ipykernel\kernelbase.py:397, in Kernel.dispatch_shell(self, msg)
#     395     result = handler(self.shell_stream, idents, msg)
#     396     if inspect.isawaitable(result):
# --> 397         await result
#     398 except Exception:
#     399     self.log.error("Exception in message handler:", exc_info=True)  # noqa: G201
#
# File c:\Users\esc\miniconda3\envs\0.12-env\Lib\site-packages\ipykernel\ipkernel.py:368, in IPythonKernel.execute_request(self, stream, ident, parent)
#     366 parent_header = extract_header(parent)
#     367 self._associate_new_top_level_threads_with(parent_header)
# --> 368 await super().execute_request(stream, ident, parent)
#
# File c:\Users\esc\miniconda3\envs\0.12-env\Lib\site-packages\ipykernel\kernelbase.py:752, in Kernel.execute_request(self, stream, ident, parent)
#     749 reply_content = self.do_execute(**do_execute_args)
#     751 if inspect.isawaitable(reply_content):
# --> 752     reply_content = await reply_content
#     754 # Flush output before sending the reply.
#     755 if sys.stdout is not None:
#
# File c:\Users\esc\miniconda3\envs\0.12-env\Lib\site-packages\ipykernel\ipkernel.py:455, in IPythonKernel.do_execute(self, code, silent, store_history, user_expressions, allow_stdin, cell_meta, cell_id)
#     450 else:
#     451     # runner isn't already running,
#     452     # make synchronous call,
#     453     # letting shell dispatch to loop runners
#     454     if accepts_params["cell_id"]:
# --> 455         res = shell.run_cell(
#     456             code,
#     457             store_history=store_history,
#     458             silent=silent,
#     459             cell_id=cell_id,
#     460         )
#     461     else:
#     462         res = shell.run_cell(code, store_history=store_history, silent=silent)
#
# File c:\Users\esc\miniconda3\envs\0.12-env\Lib\site-packages\ipykernel\zmqshell.py:577, in ZMQInteractiveShell.run_cell(self, *args, **kwargs)
#     575 """Run a cell."""
#     576 self._last_traceback = None
# --> 577 return super().run_cell(*args, **kwargs)
#
# File c:\Users\esc\miniconda3\envs\0.12-env\Lib\site-packages\IPython\core\interactiveshell.py:3116, in InteractiveShell.run_cell(self, raw_cell, store_history, silent, shell_futures, cell_id)
#    3114 with self._tee(channel="stdout"), self._tee(channel="stderr"):
#    3115     try:
# -> 3116         result = self._run_cell(
#    3117             raw_cell, store_history, silent, shell_futures, cell_id
#    3118         )
#    3119     finally:
#    3120         self.events.trigger("post_execute")
#
# File c:\Users\esc\miniconda3\envs\0.12-env\Lib\site-packages\IPython\core\interactiveshell.py:3171, in InteractiveShell._run_cell(self, raw_cell, store_history, silent, shell_futures, cell_id)
#    3168     runner = _pseudo_sync_runner
#    3170 try:
# -> 3171     result = runner(coro)
#    3172 except BaseException as e:
#    3173     try:
#
# File c:\Users\esc\miniconda3\envs\0.12-env\Lib\site-packages\IPython\core\async_helpers.py:128, in _pseudo_sync_runner(coro)
#     120 """
#     121 A runner that does not really allow async execution, and just advance the coroutine.
#     122
#    (...)    125 Credit to Nathaniel Smith
#     126 """
#     127 try:
# --> 128     coro.send(None)
#     129 except StopIteration as exc:
#     130     return exc.value
#
# File c:\Users\esc\miniconda3\envs\0.12-env\Lib\site-packages\IPython\core\interactiveshell.py:3394, in InteractiveShell.run_cell_async(self, raw_cell, store_history, silent, shell_futures, transformed_cell, preprocessing_exc_tuple, cell_id)
#    3390 # Execute the user code
#    3391 interactivity = "none" if silent else self.ast_node_interactivity
# -> 3394 has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    3395        interactivity=interactivity, compiler=compiler, result=result)
#    3397 self.last_execution_succeeded = not has_raised
#    3398 self.last_execution_result = result
#
# File c:\Users\esc\miniconda3\envs\0.12-env\Lib\site-packages\IPython\core\interactiveshell.py:3639, in InteractiveShell.run_ast_nodes(self, nodelist, cell_name, interactivity, compiler, result)
#    3637         code = compiler(mod, cell_name, mode)
#    3638         asy = compare(code)
# -> 3639     if await self.run_code(code, result, async_=asy):
#    3640         return True
#    3642 # Flush softspace
#
#     [... skipping hidden 1 frame]
#
# Cell In[11], line 17
#      14         result.append(a + b + len(list_2))
#      15     return iden(arg = result)
# ---> 17 result = loop_over_lists()
#      18 workflow = construct(result, simplify_ids=True)
#      19 cwl = render(workflow)
#
# TaskException: This iterable reference does not have a known fixed length, consider using `Fixed[...]` with a default, or typehint using `tuple[int, float]` (or similar) to tell dewret how long it should be.
# Task loop_over_lists declared in <module> at C:\Users\esc\AppData\Local\Temp\ipykernel_269664\3820651867.py:10
# @workflow()
